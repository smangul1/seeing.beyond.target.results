# %% [markdown]
# # MT and rDNA

# %%
import os
import csv
import sys

path = 'offtarget'

fileOut=open('offtarget.WXS.csv',"w")
fileOut.write('ID,cov\n')

for f in os.listdir(path):
    file=open("./offtarget/"+f)
    reader=csv.reader(file)
    cov=0.0
    count=0
    for line in reader:
            x=int(line[1])
            y=int(line[2])
            if y>x:
                if line[3]=="":
                    n=0.0
                else:
                    n=float(line[3])
                cov+=n/(y-x)
                count+=1
        
    fileOut.write(f.replace('.offtarget.cov','')+","+str(cov/count))
    fileOut.write("\n")

# %%
import pandas as pd
df = pd.read_csv('offtarget.WXS.csv')
df.head()
# Out:
#                                  ID       cov
# 0  003860a34c9b244a5d8435b220ca5673  5.390855
# 1  04dad306f9be80db39f4be578091aa11  4.966536
# 2  08886fe521e2ff176295468dc519d9f3  3.162184
# 3  09f52a751a3bd08f2fd4dcc61a046ed0  4.683656
# 4  0e66d92c70e71ca68bc7df03f140ac23  3.325347

# %%
metadata=pd.read_csv('../outcomes/PILOT.WXS.clean.metadata.csv')
metadata.head()
# Out:
#    Unnamed: 0 patientBarcode                                   ID  \
# 0           1   TCGA-05-4244  C347.TCGA-05-4244-01A-01D-1105-08.5
# 1           2   TCGA-05-4420  C347.TCGA-05-4420-01A-01D-1265-08.3
# 2           3   TCGA-05-4430  C347.TCGA-05-4430-01A-02D-1265-08.3
# 3           4   TCGA-05-5423  C509.TCGA-05-5423-01A-01D-1625-08.1
# 4           5   TCGA-17-Z004  C347.TCGA-17-Z004-01A-01W-0746-08.1
#
#                          sample platform  clinical_data_age_at_diagnosis  \
# 0  TCGA-05-4244-01A-01D-1105-08      WGS                             NaN
# 1  TCGA-05-4420-01A-01D-1265-08      WGS                             NaN
# 2  TCGA-05-4430-01A-02D-1265-08      WGS                             NaN
# 3  TCGA-05-5423-01A-01D-1625-08      WGS                             NaN
# 4  TCGA-17-Z004-01A-01W-0746-08      WGS                             NaN
#
#    clinical_data_age_at_initial_pathologic_diagnosis  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    clinical_data_agebegansmokinginyears  clinical_data_Breslow_thickness  \
# 0                                   NaN                              NaN
# 1                                   NaN                              NaN
# 2                                   NaN                              NaN
# 3                                   NaN                              NaN
# 4                                   NaN                              NaN
#
#    clinical_data_cause_of_death    ...     clinical_data_years_to_birth  \
# 0                           NaN    ...                             70.0
# 1                           NaN    ...                             41.0
# 2                           NaN    ...                             59.0
# 3                           NaN    ...                             65.0
# 4                           NaN    ...                              NaN
#
#    datasource  disease  expData  ips_ctla4_neg_pd1_neg  ips_ctla4_neg_pd1_pos  \
# 0        TCGA     LUAD        1                    8.0                    7.0
# 1        TCGA     LUAD        1                    7.0                    6.0
# 2        TCGA     LUAD        1                    8.0                    7.0
# 3        TCGA     LUAD        1                    8.0                    7.0
# 4        TCGA     LUAD        0                    NaN                    NaN
#
#    ips_ctla4_pos_pd1_neg  ips_ctla4_pos_pd1_pos  \
# 0                    7.0                    7.0
# 1                    7.0                    5.0
# 2                    7.0                    7.0
# 3                    8.0                    7.0
# 4                    NaN                    NaN
#
#                            patient_uuid  slides_0
# 0  34040b83-7e8a-4264-a551-b16621843e28       NaN
# 1  3d2aa654-1b5f-4eb4-a1c2-af31f5760069       NaN
# 2  3a23cdb5-2327-45ac-b0b5-d4afe038c757       NaN
# 3  33e3f736-7990-4f7a-ac35-863247566541       NaN
# 4  0d96def2-cf0a-4659-94e5-f08744c57cc6       NaN
#
# [5 rows x 98 columns]

# %%
data=pd.merge(df, metadata, on='ID')
data.head()
# Out:
#                                  ID       cov  Unnamed: 0 patientBarcode  \
# 0  003860a34c9b244a5d8435b220ca5673  5.390855         194   TCGA-A2-A4S1
# 1  04dad306f9be80db39f4be578091aa11  4.966536         246   TCGA-BH-A1EY
# 2  08886fe521e2ff176295468dc519d9f3  3.162184         197   TCGA-A7-A13G
# 3  09f52a751a3bd08f2fd4dcc61a046ed0  4.683656         256   TCGA-C8-A1HK
# 4  0e66d92c70e71ca68bc7df03f140ac23  3.325347         188   TCGA-A2-A25D
#
#                          sample platform  clinical_data_age_at_diagnosis  \
# 0  TCGA-A2-A4S1-01A-21D-A25Q-09      WGS                             NaN
# 1  TCGA-BH-A1EY-01A-11D-A13L-09      WGS                             NaN
# 2  TCGA-A7-A13G-01B-04D-A22N-09      WGS                             NaN
# 3  TCGA-C8-A1HK-01A-21D-A13L-09      WGS                             NaN
# 4  TCGA-A2-A25D-01A-12D-A16D-09      WGS                             NaN
#
#    clinical_data_age_at_initial_pathologic_diagnosis  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    clinical_data_agebegansmokinginyears  clinical_data_Breslow_thickness  \
# 0                                   NaN                              NaN
# 1                                   NaN                              NaN
# 2                                   NaN                              NaN
# 3                                   NaN                              NaN
# 4                                   NaN                              NaN
#
#      ...     clinical_data_years_to_birth  datasource  disease  expData  \
# 0    ...                             66.0        TCGA     BRCA        1
# 1    ...                             79.0        TCGA     BRCA        1
# 2    ...                             79.0        TCGA     BRCA        1
# 3    ...                              NaN        TCGA     BRCA        1
# 4    ...                             90.0        TCGA     BRCA        1
#
#    ips_ctla4_neg_pd1_neg  ips_ctla4_neg_pd1_pos  ips_ctla4_pos_pd1_neg  \
# 0                    9.0                    8.0                    8.0
# 1                    7.0                    6.0                    7.0
# 2                    8.0                    6.0                    7.0
# 3                    8.0                    6.0                    7.0
# 4                    9.0                    8.0                    9.0
#
#    ips_ctla4_pos_pd1_pos                          patient_uuid  slides_0
# 0                    7.0  843c8f16-5e59-40d4-9ecc-8a75375156f6       NaN
# 1                    6.0  0741b5db-4405-42ba-b63a-c6ee4f341480       NaN
# 2                    5.0  6cd9baf5-bbe0-4c1e-a87f-c53b3af22890       NaN
# 3                    6.0  52c35691-efca-42f5-a03e-02c9f872275c       NaN
# 4                    8.0  3b963d72-ba5c-467b-83c9-fbdb462510a3       NaN
#
# [5 rows x 99 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g=sns.violinplot(x="disease", y="cov", data=data)
#g=sns.stripplot(x="disease", y="cov", data=data, palette=["black"], jitter=0.05)
g.set(xlabel='Cancer type', ylabel='Off-target coverage')
g=sns.despine()
plt.xticks(rotation=90)
#plt.show(g)
plt.savefig("Off.target.coverage.png", bbox_inches='tight')

# %%
#Run this reproduce.rDNA.py. Too long to run here

# %%
import pandas as pd
metadata=pd.read_csv('../outcomes/PILOT.WXS.clean.metadata.csv')
df_5S = pd.read_csv('5S.WXS.csv')
df_58S = pd.read_csv('58S.WXS.csv')
df_28S = pd.read_csv('28S.WXS.csv')
df_18S = pd.read_csv('18S.WXS.csv')

df = pd.read_csv('offtarget.WXS.csv')
data=pd.merge(df_5S, metadata, on='ID')
data=pd.merge(data, df, on='ID')
data=pd.merge(data, df_58S, on='ID')
data=pd.merge(data, df_28S, on='ID')
data=pd.merge(data, df_18S, on='ID')


data['cov.5S.norm'] = data['cov.5S']/data['cov']
data['cov.58S.norm'] = data['cov.58S']/data['cov']
data['cov.28S.norm'] = data['cov.28S']/data['cov']
data['cov.18S.norm'] = data['cov.18S']/data['cov']


data.head()
# Out:
#                                  ID     cov.5S  Unnamed: 0 patientBarcode  \
# 0  003860a34c9b244a5d8435b220ca5673   5.696549         194   TCGA-A2-A4S1
# 1  04dad306f9be80db39f4be578091aa11  16.363066         246   TCGA-BH-A1EY
# 2  08886fe521e2ff176295468dc519d9f3   7.967727         197   TCGA-A7-A13G
# 3  09f52a751a3bd08f2fd4dcc61a046ed0  13.939041         256   TCGA-C8-A1HK
# 4  0e66d92c70e71ca68bc7df03f140ac23  13.560287         188   TCGA-A2-A25D
#
#                          sample platform  clinical_data_age_at_diagnosis  \
# 0  TCGA-A2-A4S1-01A-21D-A25Q-09      WGS                             NaN
# 1  TCGA-BH-A1EY-01A-11D-A13L-09      WGS                             NaN
# 2  TCGA-A7-A13G-01B-04D-A22N-09      WGS                             NaN
# 3  TCGA-C8-A1HK-01A-21D-A13L-09      WGS                             NaN
# 4  TCGA-A2-A25D-01A-12D-A16D-09      WGS                             NaN
#
#    clinical_data_age_at_initial_pathologic_diagnosis  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    clinical_data_agebegansmokinginyears  clinical_data_Breslow_thickness  \
# 0                                   NaN                              NaN
# 1                                   NaN                              NaN
# 2                                   NaN                              NaN
# 3                                   NaN                              NaN
# 4                                   NaN                              NaN
#
#        ...                               patient_uuid  slides_0       cov  \
# 0      ...       843c8f16-5e59-40d4-9ecc-8a75375156f6       NaN  5.390855
# 1      ...       0741b5db-4405-42ba-b63a-c6ee4f341480       NaN  4.966536
# 2      ...       6cd9baf5-bbe0-4c1e-a87f-c53b3af22890       NaN  3.162184
# 3      ...       52c35691-efca-42f5-a03e-02c9f872275c       NaN  4.683656
# 4      ...       3b963d72-ba5c-467b-83c9-fbdb462510a3       NaN  3.325347
#
#        cov.58S     cov.28S     cov.18S  cov.5S.norm  cov.58S.norm  \
# 0  2834.899371   70.610746  130.710005     1.056706    525.871894
# 1   946.503145  194.582090  261.747994     3.294664    190.576112
# 2  3307.685535   18.621891  157.719101     2.519691   1046.013017
# 3   984.308176  200.056119  286.082397     2.976103    210.158105
# 4   856.628931  165.016119  286.418941     4.077857    257.605910
#
#    cov.28S.norm  cov.18S.norm
# 0     13.098245     24.246617
# 1     39.178632     52.702324
# 2      5.888933     49.876638
# 3     42.713670     61.081007
# 4     49.623736     86.132057
#
# [5 rows x 107 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g=sns.violinplot(x="disease", y="cov.5S.norm", data=data)
#g=sns.stripplot(x="disease", y="cov.5S.norm", data=data, palette=["black"], jitter=0.05)
g.set(xlabel='Cancer type', ylabel='rDNA (5S) dosage')
g=sns.despine()
plt.xticks(rotation=90)
plt.savefig("5S.dosage.png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g=sns.violinplot(x="disease", y="cov.58S.norm", data=data)
#g=sns.stripplot(x="disease", y="cov.58S.norm", data=data, palette=["black"], jitter=0.05)
g.set(xlabel='Cancer type', ylabel='rDNA (5.8S) dosage')
g=sns.despine()
plt.xticks(rotation=90)
plt.savefig("5.8S.dosage.png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g=sns.violinplot(x="disease", y="cov.18S.norm", data=data)
#g=sns.stripplot(x="disease", y="cov.18S.norm", data=data, palette=["black"], jitter=0.05)
g.set(xlabel='Cancer type', ylabel='rDNA (18S) dosage')
g=sns.despine()
plt.xticks(rotation=90)
plt.savefig("18S.dosage.png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g=sns.violinplot(x="disease", y="cov.28S.norm", data=data)
g.set(xlabel='Cancer type', ylabel='rDNA (28S) dosage')
g=sns.despine()
plt.xticks(rotation=90)
plt.savefig("28S.dosage.png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

g=sns.set_style("white")
g=sns.set_context("talk")
g=sns.regplot(x="cov.58S.norm", y="cov.18S.norm", data=data,color="black")
g.set(xlabel='rDNA (5.8S) dosage', ylabel='rDNA (18S) dosage')
g=sns.despine()
#plt.show(g)
plt.savefig("18S.vs.58S.png", bbox_inches='tight')

stats.pearsonr(data['cov.18S.norm'], data['cov.58S.norm'])
# Out:
# (-0.05766511360527331, 0.46191140343473147)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

g=sns.set_style("white")
g=sns.set_context("talk")
g=sns.regplot(x="cov.18S.norm", y="cov.28S.norm", data=data,color="black")
g.set(xlabel='rDNA (18S) dosage', ylabel='rDNA (28S) dosage')
g=sns.despine()
#plt.show(g)
plt.savefig("18S.vs.28S.png", bbox_inches='tight')

stats.pearsonr(data['cov.28S.norm'], data['cov.18S.norm'])
# Out:
# (0.9547869543398257, 8.782522740921786e-88)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

g=sns.set_style("white")
g=sns.set_context("talk")
g=sns.regplot(x="cov.5S.norm", y="cov.18S.norm", data=data,color="black")
g.set(xlabel='rDNA (5S) dosage', ylabel='rDNA (18S) dosage')
g=sns.despine()
#plt.show(g)
plt.savefig("18S.vs.5S.png", bbox_inches='tight')

stats.pearsonr(data['cov.18S.norm'], data['cov.5S.norm'])
# Out:
# (0.9439347651596925, 2.3227710543835097e-80)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

g=sns.set_style("white")
g=sns.set_context("talk")
g=sns.regplot(x="cov.5S.norm", y="cov.28S.norm", data=data,color="black")
g.set(xlabel='rDNA (5SS) dosage', ylabel='rDNA (28S) dosage')

g=sns.despine()
#plt.show(g)
plt.savefig("28S.vs.5S.png", bbox_inches='tight')

stats.pearsonr(data['cov.28S.norm'], data['cov.5S.norm'])
# Out:
# (0.9431981250855755, 6.530571899633595e-80)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

g=sns.set_style("white")
g=sns.set_context("talk")
g=sns.regplot(x="cov.5S.norm", y="cov.58S.norm", data=data,color="black")
g.set(xlabel='5S dosage', ylabel='5.8S dosage')
g.set(xlabel='rDNA (5SS) dosage', ylabel='rDNA (5.8S) dosage')

g=sns.despine()
#plt.show(g)
plt.savefig("28S.vs.58S.pdf", bbox_inches='tight')

stats.pearsonr(data['cov.28S.norm'], data['cov.58S.norm'])
# Out:
# (-0.03248076657261367, 0.67875659632249)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

data_58S_cov=pd.read_csv('58S.WXS.raw.csv.gz',compression='gzip')
#data_58S_cov=pd.read_csv('test2.txt')
metadata=pd.read_csv('../outcomes/PILOT.WXS.clean.metadata.csv')
data_58S_cov=pd.merge(data_58S_cov, metadata, on='ID')
data_58S_cov.head()
# Out:
#                                  ID  pos  cov  Unnamed: 0 patientBarcode  \
# 0  003860a34c9b244a5d8435b220ca5673    1    0         194   TCGA-A2-A4S1
# 1  003860a34c9b244a5d8435b220ca5673    2  339         194   TCGA-A2-A4S1
# 2  003860a34c9b244a5d8435b220ca5673    3  583         194   TCGA-A2-A4S1
# 3  003860a34c9b244a5d8435b220ca5673    4  715         194   TCGA-A2-A4S1
# 4  003860a34c9b244a5d8435b220ca5673    5  805         194   TCGA-A2-A4S1
#
#                          sample platform  clinical_data_age_at_diagnosis  \
# 0  TCGA-A2-A4S1-01A-21D-A25Q-09      WGS                             NaN
# 1  TCGA-A2-A4S1-01A-21D-A25Q-09      WGS                             NaN
# 2  TCGA-A2-A4S1-01A-21D-A25Q-09      WGS                             NaN
# 3  TCGA-A2-A4S1-01A-21D-A25Q-09      WGS                             NaN
# 4  TCGA-A2-A4S1-01A-21D-A25Q-09      WGS                             NaN
#
#    clinical_data_age_at_initial_pathologic_diagnosis  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    clinical_data_agebegansmokinginyears    ...     \
# 0                                   NaN    ...
# 1                                   NaN    ...
# 2                                   NaN    ...
# 3                                   NaN    ...
# 4                                   NaN    ...
#
#    clinical_data_years_to_birth  datasource  disease  expData  \
# 0                          66.0        TCGA     BRCA        1
# 1                          66.0        TCGA     BRCA        1
# 2                          66.0        TCGA     BRCA        1
# 3                          66.0        TCGA     BRCA        1
# 4                          66.0        TCGA     BRCA        1
#
#    ips_ctla4_neg_pd1_neg  ips_ctla4_neg_pd1_pos  ips_ctla4_pos_pd1_neg  \
# 0                    9.0                    8.0                    8.0
# 1                    9.0                    8.0                    8.0
# 2                    9.0                    8.0                    8.0
# 3                    9.0                    8.0                    8.0
# 4                    9.0                    8.0                    8.0
#
#    ips_ctla4_pos_pd1_pos                          patient_uuid  slides_0
# 0                    7.0  843c8f16-5e59-40d4-9ecc-8a75375156f6       NaN
# 1                    7.0  843c8f16-5e59-40d4-9ecc-8a75375156f6       NaN
# 2                    7.0  843c8f16-5e59-40d4-9ecc-8a75375156f6       NaN
# 3                    7.0  843c8f16-5e59-40d4-9ecc-8a75375156f6       NaN
# 4                    7.0  843c8f16-5e59-40d4-9ecc-8a75375156f6       NaN
#
# [5 rows x 100 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import sys

g=sns.set_style("white")
g=sns.set_context("talk")
g=sns.despine()


dfList = set(data_58S_cov['ID'].tolist())


for x in dfList:
    data_local=data_58S_cov[data_58S_cov['ID'] == x]
    #df = create_df_with(x)
    #plt.figure() #this creates a new figure on which your plot will appear
    d=data_local['disease'].tolist()[0]
    if d=='BRCA':
        g=sns.lineplot(x="pos",y="cov",legend=False,data=data_local,color='yellow',linewidth=1)
    elif d=='LUSC':
        g=sns.lineplot(x="pos",y="cov",legend=False,data=data_local,color='green',linewidth=1)
    elif d=='SKCM':
        g=sns.lineplot(x="pos",y="cov",legend=False,data=data_local,color='red',linewidth=1)
    elif d=='PRAD':
        g=sns.lineplot(x="pos",y="cov",legend=False,data=data_local,color='blue',linewidth=1)
    elif d=='LUAD':
        g=sns.lineplot(x="pos",y="cov",legend=False,data=data_local,color='black',linewidth=1)


g.set_ylabel('Depth of coverage')  
g.set_xlabel('Coordinates') 
g.figure.savefig("5.8S.coverage.png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

data_18S_cov=pd.read_csv('18S.WXS.raw.csv.gz',compression='gzip')
#data_58S_cov=pd.read_csv('test2.txt')
metadata=pd.read_csv('../outcomes/PILOT.WXS.clean.metadata.csv')
data_18S_cov=pd.merge(data_18S_cov, metadata, on='ID')
data_18S_cov.head()
# Out:
#                                  ID  pos  cov  Unnamed: 0 patientBarcode  \
# 0  003860a34c9b244a5d8435b220ca5673    1    0         194   TCGA-A2-A4S1
# 1  003860a34c9b244a5d8435b220ca5673    2    5         194   TCGA-A2-A4S1
# 2  003860a34c9b244a5d8435b220ca5673    3    7         194   TCGA-A2-A4S1
# 3  003860a34c9b244a5d8435b220ca5673    4   11         194   TCGA-A2-A4S1
# 4  003860a34c9b244a5d8435b220ca5673    5   11         194   TCGA-A2-A4S1
#
#                          sample platform  clinical_data_age_at_diagnosis  \
# 0  TCGA-A2-A4S1-01A-21D-A25Q-09      WGS                             NaN
# 1  TCGA-A2-A4S1-01A-21D-A25Q-09      WGS                             NaN
# 2  TCGA-A2-A4S1-01A-21D-A25Q-09      WGS                             NaN
# 3  TCGA-A2-A4S1-01A-21D-A25Q-09      WGS                             NaN
# 4  TCGA-A2-A4S1-01A-21D-A25Q-09      WGS                             NaN
#
#    clinical_data_age_at_initial_pathologic_diagnosis  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    clinical_data_agebegansmokinginyears    ...     \
# 0                                   NaN    ...
# 1                                   NaN    ...
# 2                                   NaN    ...
# 3                                   NaN    ...
# 4                                   NaN    ...
#
#    clinical_data_years_to_birth  datasource  disease  expData  \
# 0                          66.0        TCGA     BRCA        1
# 1                          66.0        TCGA     BRCA        1
# 2                          66.0        TCGA     BRCA        1
# 3                          66.0        TCGA     BRCA        1
# 4                          66.0        TCGA     BRCA        1
#
#    ips_ctla4_neg_pd1_neg  ips_ctla4_neg_pd1_pos  ips_ctla4_pos_pd1_neg  \
# 0                    9.0                    8.0                    8.0
# 1                    9.0                    8.0                    8.0
# 2                    9.0                    8.0                    8.0
# 3                    9.0                    8.0                    8.0
# 4                    9.0                    8.0                    8.0
#
#    ips_ctla4_pos_pd1_pos                          patient_uuid  slides_0
# 0                    7.0  843c8f16-5e59-40d4-9ecc-8a75375156f6       NaN
# 1                    7.0  843c8f16-5e59-40d4-9ecc-8a75375156f6       NaN
# 2                    7.0  843c8f16-5e59-40d4-9ecc-8a75375156f6       NaN
# 3                    7.0  843c8f16-5e59-40d4-9ecc-8a75375156f6       NaN
# 4                    7.0  843c8f16-5e59-40d4-9ecc-8a75375156f6       NaN
#
# [5 rows x 100 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import sys

g=sns.set_style("white")
g=sns.set_context("talk")


dfList = set(data_18S_cov['ID'].tolist())


for x in dfList:
    data_local=data_18S_cov[data_18S_cov['ID'] == x]
    #df = create_df_with(x)
    #plt.figure() #this creates a new figure on which your plot will appear
    d=data_local['disease'].tolist()[0]
    if d=='BRCA':
        g=sns.lineplot(x="pos",y="cov",legend=False,data=data_local,color='yellow',linewidth=1)
    elif d=='LUSC':
        g=sns.lineplot(x="pos",y="cov",legend=False,data=data_local,color='green',linewidth=1)
    elif d=='SKCM':
        g=sns.lineplot(x="pos",y="cov",legend=False,data=data_local,color='red',linewidth=1)
    elif d=='PRAD':
        g=sns.lineplot(x="pos",y="cov",legend=False,data=data_local,color='blue',linewidth=1)
    elif d=='LUAD':
        sns.lineplot(x="pos",y="cov",legend=False,data=data_local,color='black',linewidth=1)
    
    
g.set_ylabel('Depth')  
g.set_xlabel('Coordinates') 
g.figure.savefig("18S.coverage.pdf", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

data_28S_cov=pd.read_csv('28S.WXS.raw.csv.gz',compression='gzip')
#data_58S_cov=pd.read_csv('test2.txt')
metadata=pd.read_csv('../outcomes/PILOT.WXS.clean.metadata.csv')
data_28S_cov=pd.merge(data_28S_cov, metadata, on='ID')
data_28S_cov.head()
# Out:
#                                  ID  pos  cov  Unnamed: 0 patientBarcode  \
# 0  003860a34c9b244a5d8435b220ca5673    1    0         194   TCGA-A2-A4S1
# 1  003860a34c9b244a5d8435b220ca5673    2   37         194   TCGA-A2-A4S1
# 2  003860a34c9b244a5d8435b220ca5673    3   45         194   TCGA-A2-A4S1
# 3  003860a34c9b244a5d8435b220ca5673    4   57         194   TCGA-A2-A4S1
# 4  003860a34c9b244a5d8435b220ca5673    5   62         194   TCGA-A2-A4S1
#
#                          sample platform  clinical_data_age_at_diagnosis  \
# 0  TCGA-A2-A4S1-01A-21D-A25Q-09      WGS                             NaN
# 1  TCGA-A2-A4S1-01A-21D-A25Q-09      WGS                             NaN
# 2  TCGA-A2-A4S1-01A-21D-A25Q-09      WGS                             NaN
# 3  TCGA-A2-A4S1-01A-21D-A25Q-09      WGS                             NaN
# 4  TCGA-A2-A4S1-01A-21D-A25Q-09      WGS                             NaN
#
#    clinical_data_age_at_initial_pathologic_diagnosis  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    clinical_data_agebegansmokinginyears    ...     \
# 0                                   NaN    ...
# 1                                   NaN    ...
# 2                                   NaN    ...
# 3                                   NaN    ...
# 4                                   NaN    ...
#
#    clinical_data_years_to_birth  datasource  disease  expData  \
# 0                          66.0        TCGA     BRCA        1
# 1                          66.0        TCGA     BRCA        1
# 2                          66.0        TCGA     BRCA        1
# 3                          66.0        TCGA     BRCA        1
# 4                          66.0        TCGA     BRCA        1
#
#    ips_ctla4_neg_pd1_neg  ips_ctla4_neg_pd1_pos  ips_ctla4_pos_pd1_neg  \
# 0                    9.0                    8.0                    8.0
# 1                    9.0                    8.0                    8.0
# 2                    9.0                    8.0                    8.0
# 3                    9.0                    8.0                    8.0
# 4                    9.0                    8.0                    8.0
#
#    ips_ctla4_pos_pd1_pos                          patient_uuid  slides_0
# 0                    7.0  843c8f16-5e59-40d4-9ecc-8a75375156f6       NaN
# 1                    7.0  843c8f16-5e59-40d4-9ecc-8a75375156f6       NaN
# 2                    7.0  843c8f16-5e59-40d4-9ecc-8a75375156f6       NaN
# 3                    7.0  843c8f16-5e59-40d4-9ecc-8a75375156f6       NaN
# 4                    7.0  843c8f16-5e59-40d4-9ecc-8a75375156f6       NaN
#
# [5 rows x 100 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import sys

g=sns.set_style("white")
g=sns.set_context("talk")


dfList = set(data_28S_cov['ID'].tolist())


for x in dfList:
    data_local=data_28S_cov[data_28S_cov['ID'] == x]
    #df = create_df_with(x)
    #plt.figure() #this creates a new figure on which your plot will appear
    d=data_local['disease'].tolist()[0]
    if d=='BRCA':
        g=sns.lineplot(x="pos",y="cov",legend=False,data=data_local,color='yellow',linewidth=1)
    elif d=='LUSC':
        g=sns.lineplot(x="pos",y="cov",legend=False,data=data_local,color='green',linewidth=1)
    elif d=='SKCM':
        g=sns.lineplot(x="pos",y="cov",legend=False,data=data_local,color='red',linewidth=1)
    elif d=='PRAD':
        g=sns.lineplot(x="pos",y="cov",legend=False,data=data_local,color='blue',linewidth=1)
    elif d=='LUAD':
        sns.lineplot(x="pos",y="cov",legend=False,data=data_local,color='black',linewidth=1)
    
    
g.set_ylabel('Depth')  
g.set_xlabel('Coordinates') 
g.figure.savefig("28S.coverage.pdf", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

data_5S_cov=pd.read_csv('5S.WXS.raw.csv.gz',compression='gzip')
#data_58S_cov=pd.read_csv('test2.txt')
metadata=pd.read_csv('../outcomes/PILOT.WXS.clean.metadata.csv')
data_5S_cov=pd.merge(data_5S_cov, metadata, on='ID')
data_5S_cov.head()
# Out:
#                                  ID  pos  cov  Unnamed: 0 patientBarcode  \
# 0  003860a34c9b244a5d8435b220ca5673    1    0         194   TCGA-A2-A4S1
# 1  003860a34c9b244a5d8435b220ca5673    2    0         194   TCGA-A2-A4S1
# 2  003860a34c9b244a5d8435b220ca5673    3    0         194   TCGA-A2-A4S1
# 3  003860a34c9b244a5d8435b220ca5673    4    0         194   TCGA-A2-A4S1
# 4  003860a34c9b244a5d8435b220ca5673    5    0         194   TCGA-A2-A4S1
#
#                          sample platform  clinical_data_age_at_diagnosis  \
# 0  TCGA-A2-A4S1-01A-21D-A25Q-09      WGS                             NaN
# 1  TCGA-A2-A4S1-01A-21D-A25Q-09      WGS                             NaN
# 2  TCGA-A2-A4S1-01A-21D-A25Q-09      WGS                             NaN
# 3  TCGA-A2-A4S1-01A-21D-A25Q-09      WGS                             NaN
# 4  TCGA-A2-A4S1-01A-21D-A25Q-09      WGS                             NaN
#
#    clinical_data_age_at_initial_pathologic_diagnosis  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    clinical_data_agebegansmokinginyears    ...     \
# 0                                   NaN    ...
# 1                                   NaN    ...
# 2                                   NaN    ...
# 3                                   NaN    ...
# 4                                   NaN    ...
#
#    clinical_data_years_to_birth  datasource  disease  expData  \
# 0                          66.0        TCGA     BRCA        1
# 1                          66.0        TCGA     BRCA        1
# 2                          66.0        TCGA     BRCA        1
# 3                          66.0        TCGA     BRCA        1
# 4                          66.0        TCGA     BRCA        1
#
#    ips_ctla4_neg_pd1_neg  ips_ctla4_neg_pd1_pos  ips_ctla4_pos_pd1_neg  \
# 0                    9.0                    8.0                    8.0
# 1                    9.0                    8.0                    8.0
# 2                    9.0                    8.0                    8.0
# 3                    9.0                    8.0                    8.0
# 4                    9.0                    8.0                    8.0
#
#    ips_ctla4_pos_pd1_pos                          patient_uuid  slides_0
# 0                    7.0  843c8f16-5e59-40d4-9ecc-8a75375156f6       NaN
# 1                    7.0  843c8f16-5e59-40d4-9ecc-8a75375156f6       NaN
# 2                    7.0  843c8f16-5e59-40d4-9ecc-8a75375156f6       NaN
# 3                    7.0  843c8f16-5e59-40d4-9ecc-8a75375156f6       NaN
# 4                    7.0  843c8f16-5e59-40d4-9ecc-8a75375156f6       NaN
#
# [5 rows x 100 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import sys

g=sns.set_style("white")
g=sns.set_context("talk")


dfList = set(data_5S_cov['ID'].tolist())


for x in dfList:
    data_local=data_5S_cov[data_5S_cov['ID'] == x]
    #df = create_df_with(x)
    #plt.figure() #this creates a new figure on which your plot will appear
    d=data_local['disease'].tolist()[0]
    if d=='BRCA':
        g=sns.lineplot(x="pos",y="cov",legend=False,data=data_local,color='yellow',linewidth=1)
    elif d=='LUSC':
        g=sns.lineplot(x="pos",y="cov",legend=False,data=data_local,color='green',linewidth=1)
    elif d=='SKCM':
        g=sns.lineplot(x="pos",y="cov",legend=False,data=data_local,color='red',linewidth=1)
    elif d=='PRAD':
        g=sns.lineplot(x="pos",y="cov",legend=False,data=data_local,color='blue',linewidth=1)
    elif d=='LUAD':
        sns.lineplot(x="pos",y="cov",legend=False,data=data_local,color='black',linewidth=1)
    
    
g.set_ylabel('Depth')  
g.set_xlabel('Coordinates') 
g.figure.savefig("5S.coverage.pdf", bbox_inches='tight')
