# %%
import os
import csv
import sys

path = 'offtarget'


for f in os.listdir(path):
    file=open("./offtarget/"+f)
    reader=csv.reader(file)
    cov=0.0
    for line in reader:
            x=int(line[1])
            y=int(line[2])
            if y>x:
                if line[3]=="":
                    n=0.0
                else:
                    n=float(line[3])
                print line,n/(y-x)
    sys.exit(1)    
    print cov
# Out:
#  ['1', '1', '11873', '3446'] 0.290262803235
# ['1', '29962', '69090', '439062'] 11.2211715396
# ['1', '70009', '134772', '374115'] 5.77667804147
# ['1', '140567', '700244', '2827611'] 5.05221940512
# ['1', '714069', '761585', '410390'] 8.63688020877
# ['1', '762903', '762970', '1576'] 23.5223880597
# ['1', '794827', '803450', '154115'] 17.8725501566
# ['1', '812183', '852952', '31938'] 0.78338933994
# ['1', '854818', '860529', '7528'] 1.31815794082
# ['1', '894680', '895966', '1237'] 0.961897356143
# ['1', '901100', '901876', '3185'] 4.1043814433
# ['1', '910485', '910578', '300'] 3.22580645161
# ['1', '917474', '934341', '16298'] 0.966265488824
# ['1', '935553', '948846', '20734'] 1.5597682991
# ['1', '949920', '955502', '8099'] 1.45091365102
# ['1', '991500', '1007125', '180480'] 11.55072
# ['1', '1009688', '1017197', '8021'] 1.06818484485
# ['1', '1051737', '1072396', '23228'] 1.12435258241
# ['1', '1079435', '1102483', '43953'] 1.9070201319
# ...
